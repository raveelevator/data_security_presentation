# %%
# Dependencies and Setup
# %matplotlib inline
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.patches import ConnectionPatch


# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
cyber_security_breaches_data_to_load = "resources/Cyber_Security_Breaches.csv"
cyberattacks_data_to_load = "resources/cyberattacks.csv"

Cyber_Security_Breaches = pd.read_csv(cyber_security_breaches_data_to_load, encoding="ISO-8859-1")
cyberattacks_data = pd.read_csv(cyberattacks_data_to_load, encoding="ISO-8859-1")

# Read the Csv Files together Joining them
all_data = pd.merge(Cyber_Security_Breaches, cyberattacks_data, how="inner", on=["Year"])
# Combine the data into a single dataset

all_data.head(50)
# Cyber_Security_Breaches.head()
# cyberattacks_data.head(50)
# Out:
#     Unnamed: 0  Number    Name_of_Covered_Entity State  \
# 0           28      27       Ashley and Gray DDS    MO
# 1           28      27       Ashley and Gray DDS    MO
# 2           28      27       Ashley and Gray DDS    MO
# 3           28      27       Ashley and Gray DDS    MO
# 4           28      27       Ashley and Gray DDS    MO
# 5           28      27       Ashley and Gray DDS    MO
# 6           28      27       Ashley and Gray DDS    MO
# 7           28      27       Ashley and Gray DDS    MO
# 8           28      27       Ashley and Gray DDS    MO
# 9           28      27       Ashley and Gray DDS    MO
# 10          28      27       Ashley and Gray DDS    MO
# 11          28      27       Ashley and Gray DDS    MO
# 12          28      27       Ashley and Gray DDS    MO
# 13          28      27       Ashley and Gray DDS    MO
# 14          28      27       Ashley and Gray DDS    MO
# 15          28      27       Ashley and Gray DDS    MO
# ...

# %%
cols = list(all_data)
cols.insert(0, cols.pop(cols.index('Year')))
cols
# Out:
# ['Year',
#  'Unnamed: 0',
#  'Number',
#  'Name_of_Covered_Entity',
#  'State',
#  'Business_Associate_Involved',
#  'Individuals_Affected',
#  'Date_of_Breach',
#  'Type_of_Breach',
#  'Location_of_Breached_Information',
#  'Date_Posted_or_Updated',
#  'Summary',
#  'breach_start',
#  'breach_end',
#  'Entity ',
#  'Records ',
#  'Organization Type ',
#  'Method ']

# %%
all_data = all_data.ix[:, cols]
all_data.head(50)
# Out:
#     Year  Unnamed: 0  Number    Name_of_Covered_Entity State  \
# 0   2010          28      27       Ashley and Gray DDS    MO
# 1   2010          28      27       Ashley and Gray DDS    MO
# 2   2010          28      27       Ashley and Gray DDS    MO
# 3   2010          28      27       Ashley and Gray DDS    MO
# 4   2010          28      27       Ashley and Gray DDS    MO
# 5   2010          28      27       Ashley and Gray DDS    MO
# 6   2010          28      27       Ashley and Gray DDS    MO
# 7   2010          28      27       Ashley and Gray DDS    MO
# 8   2010          28      27       Ashley and Gray DDS    MO
# 9   2010          28      27       Ashley and Gray DDS    MO
# 10  2010          28      27       Ashley and Gray DDS    MO
# 11  2010          28      27       Ashley and Gray DDS    MO
# 12  2010          28      27       Ashley and Gray DDS    MO
# 13  2010          28      27       Ashley and Gray DDS    MO
# ...

# %%
all_data.columns
# Out:
# Index(['Year', 'Unnamed: 0', 'Number', 'Name_of_Covered_Entity', 'State',
#        'Business_Associate_Involved', 'Individuals_Affected', 'Date_of_Breach',
#        'Type_of_Breach', 'Location_of_Breached_Information',
#        'Date_Posted_or_Updated', 'Summary', 'breach_start', 'breach_end',
#        'Entity ', 'Records ', 'Organization Type ', 'Method '],
#       dtype='object')

# %%
security_data = all_data[['Year', 'Location_of_Breached_Information', 'Method ', 'Type_of_Breach', 'Entity ', 'Organization Type ', 'Summary', 'Individuals_Affected']].copy()
security_data.head(500)
# Out:
#      Year Location_of_Breached_Information                 Method   \
# 0    2010                 Desktop Computer                  hacked
# 1    2010                 Desktop Computer                  hacked
# 2    2010                 Desktop Computer                  hacked
# 3    2010                 Desktop Computer  lost / stolen computer
# 4    2010                 Desktop Computer     lost / stolen media
# ..    ...                              ...                     ...
# 495  2010                           Laptop     lost / stolen media
# 496  2010                           Laptop     lost / stolen media
# 497  2010                           Laptop              inside job
# 498  2010                           Laptop              inside job
# 499  2010                           Laptop  accidentally published
#
#     Type_of_Breach                                            Entity   \
# 0            Theft             Ankle & Foot Center of Tampa Bay, Inc.
# ...

# %%
# Using .rename(columns={}) in order to rename columns --- GJM

new_security_data = security_data.rename(columns={"Type_of_Breach": "Type of Breach",
                                                  "Entity ":"Name of Business",
                                                  "Method ":"Method of Breach",
                                                  "Location_of_Breached_Information":"Place of Info Breach",
                                                  "Individuals_Affected": "Individuals Affected",
                                                  "Summary":"Summary of Events",
                                                  "Organization Type ": "Organization Type"})
new_security_data.head(100)
# Out:
#     Year Place of Info Breach        Method of Breach Type of Breach  \
# 0   2010     Desktop Computer                  hacked          Theft
# 1   2010     Desktop Computer                  hacked          Theft
# 2   2010     Desktop Computer                  hacked          Theft
# 3   2010     Desktop Computer  lost / stolen computer          Theft
# 4   2010     Desktop Computer     lost / stolen media          Theft
# ..   ...                  ...                     ...            ...
# 95  2010                Paper     lost / stolen media          Theft
# 96  2010                Paper     lost / stolen media          Theft
# 97  2010                Paper              inside job          Theft
# 98  2010                Paper              inside job          Theft
# 99  2010                Paper  accidentally published          Theft
#
#                                      Name of Business Organization Type  \
# ...

# %%
# I filtered the data so that only Financial Data is in the DataFrame --- GJM
new_security_financial_data = new_security_data.loc[new_security_data["Organization Type"] == "Financial", :]
new_security_financial_data.head(100)
# Out:
#      Year      Place of Info Breach     Method of Breach Type of Breach  \
# 4    2010          Desktop Computer  lost / stolen media          Theft
# 7    2010          Desktop Computer               hacked          Theft
# 9    2010          Desktop Computer  lost / stolen media          Theft
# 24   2010                     Other  lost / stolen media          Theft
# 27   2010                     Other               hacked          Theft
# ..    ...                       ...                  ...            ...
# 629  2010                     Other  lost / stolen media           Loss
# 644  2010              Other, Paper  lost / stolen media          Theft
# 647  2010              Other, Paper               hacked          Theft
# 649  2010              Other, Paper  lost / stolen media          Theft
# 664  2010  Laptop, Desktop Computer  lost / stolen media          Theft
#
#                               Name of Business Organization Type  \
# ...

# %%
new_security_financial_data['Place of Info Breach'] = new_security_financial_data['Place of Info Breach'].replace({'Desktop Computer, Network Server, E-mail, Electronic Medical Record, Paper': 'Desktop Other',
                                                             'Laptop, Network Server, E-mail': 'Laptop',
                                                             'Laptop, Network Server': 'Laptop',
                                                             'Laptop, Electronic Medical Record': 'Laptop',
                                                             'Desktop Computer, Other Portable Electronic Device, Other': 'Desktop',
                                                             'Laptop, Other Portable Electronic Device, Paper': 'Desktop',
                                                             'Laptop, Desktop Computer, Other Portable Electronic Device, Other': 'Desktop',
                                                             'Laptop, Desktop Computer, Network Server, E-mail, Other Portable Electronic Device, Other, Electronic Medical Record, Paper': 'Desktop Other',
                                                             'Laptop, Desktop Computer, Other Portable Electronic Device': 'Desktop Other',
                                                             'Desktop Computer, Other Portable Electronic Device': 'Desktop',
                                                             'Desktop Computer, Electronic Medical Record': 'Desktop',
                                                             'Desktop Computer, Other': 'Desktop ',
                                                             'Desktop Computer, E-mail': 'Desktop',
                                                             'Other Portable Electronic Device': 'Other Portable Electronic Device, Other, Electronic Medical Record',
                                                             'Other Portable Electronic Device, Other, Electronic Medical Record': 'Other Portable Electronic Device, Other',
                                                             'Desktop Computer, E-mail': 'Desktop',
                                                             'Network Server, Other': 'Network Server',
                                                             'Network Server, Electronic Medical Record': 'Network Server',
                                                             'Network Server, E-mail': 'Network Server',
                                                             'E-mail, Other Portable Electronic Device': 'Other Portable Electronic Device, Other, Electronic Medical Record',
                                                             'Laptop, Paper': 'Laptop',
                                                             'Desktop Other': 'Desktop',
                                                             'Electronic Medical Record, Paper': 'Electronic Medical Record',
                                                             'Other, Paper': 'Other',
                                                             'Laptop, Desktop Computer': 'Laptop',
                                                             'Desktop': 'Desktop Computer',
                                                             'Other Portable Electronic Device, Other, Electronic Medical Record': 'Other Portable Electronic Device, Other',
                                                             'Other, Electronic Medical Record': 'Other Portable Electronic Device, Other, Electronic Medical Record',
                                                             'Desktop Computer, Paper': 'Desktop',
                                                             'Desktop Computer, Network Server': 'Desktop',
                                                             'Laptop, Desktop Computer, Network Server, E-mail': 'Desktop',
                                                             'Laptop, Other Portable Electronic Device': 'Laptop',
                                                             'Laptop, Desktop Computer, Network Server, E-mail, Other Portable Electronic Device, Other, Electronic Medical Record': 'Desktop Other',
                                                             'Desktop Computer, Network Server, Other Portable Electronic Device, Other': 'Desktop Other'})

# %%
# new_security_financial_data.value_counts()
new_security_financial_data["Place of Info Breach"].value_counts()
# Out:
# Laptop                                     619
# Paper                                      587
# Desktop Computer                           410
# Other Portable Electronic Device, Other    325
# Other                                      297
# Network Server                             270
# E-mail                                     133
# Electronic Medical Record                   65
# Name: Place of Info Breach, dtype: int64

# %%
new_security_financial_data
# Out:
#        Year Place of Info Breach     Method of Breach  \
# 4      2010     Desktop Computer  lost / stolen media
# 7      2010     Desktop Computer               hacked
# 9      2010     Desktop Computer  lost / stolen media
# 24     2010                Other  lost / stolen media
# 27     2010                Other               hacked
# ...     ...                  ...                  ...
# 26184  2014               E-mail               hacked
# 26199  2014     Desktop Computer               hacked
# 26202  2014     Desktop Computer               hacked
# 26203  2014     Desktop Computer           inside job
# 26209  2014     Desktop Computer               hacked
#
#                        Type of Breach  \
# 4                               Theft
# 7                               Theft
# 9                               Theft
# 24                              Theft
# 27                              Theft
# ...                               ...
# 26184  Unauthorized Access/Disclosure
# ...

# %%
# new_security_financial_data["Place of Info Breach"].head()
# new_security_financial_data.value_counts()

# %%
placeOfInfoBreachCounts = new_security_financial_data["Place of Info Breach"].value_counts()
placeOfInfoBreachCounts.plot.bar(color='b', alpha=0.75, align="center")
# plt.savefig('place_of_info_breach.png')
plt.savefig('place_of_info_breach.png', bbox_inches = "tight")





# , rot='45'
# plt.tight_layout()

# %% [markdown]
# <h1>Adding the Laptop and Desktop together!<h1>

# %%
new_security_financial_data['Place of Info Breach'] = new_security_financial_data['Place of Info Breach'].replace({'Desktop Computer, Network Server, E-mail, Electronic Medical Record, Paper': 'Desktop Other',
                                                             'Laptop, Network Server, E-mail': 'Laptop',
                                                             'Laptop, Network Server': 'Laptop',
                                                             'Laptop, Electronic Medical Record': 'Laptop',
                                                             'Desktop Computer, Other Portable Electronic Device, Other': 'Desktop',
                                                             'Laptop, Other Portable Electronic Device, Paper': 'Desktop',
                                                             'Laptop, Desktop Computer, Other Portable Electronic Device, Other': 'Desktop',
                                                             'Laptop, Desktop Computer, Network Server, E-mail, Other Portable Electronic Device, Other, Electronic Medical Record, Paper': 'Desktop Other',
                                                             'Laptop, Desktop Computer, Other Portable Electronic Device': 'Desktop Other',
                                                             'Desktop Computer, Other Portable Electronic Device': 'Desktop',
                                                             'Desktop Computer, Electronic Medical Record': 'Desktop',
                                                             'Desktop Computer, Other': 'Desktop ',
                                                             'Desktop Computer, E-mail': 'Desktop',
                                                             'Other Portable Electronic Device': 'Other Portable Electronic Device, Other, Electronic Medical Record',
                                                             'Other Portable Electronic Device, Other, Electronic Medical Record': 'Other Portable Electronic Device, Other',
                                                             'Desktop Computer, E-mail': 'Desktop',
                                                             'Network Server, Other': 'Network Server',
                                                             'Network Server, Electronic Medical Record': 'Network Server',
                                                             'Network Server, E-mail': 'Network Server',
                                                             'E-mail, Other Portable Electronic Device': 'Other Portable Electronic Device, Other, Electronic Medical Record',
                                                             'Laptop, Paper': 'Laptop',
                                                             'Desktop Other': 'Desktop',
                                                             'Electronic Medical Record, Paper': 'Electronic Medical Record',
                                                             'Other, Paper': 'Other',
                                                             'Laptop': 'Desktop Computer',
                                                             'Laptop, Desktop Computer': 'Laptop',
                                                             'Desktop': 'Desktop Computer',
                                                             'Other Portable Electronic Device, Other, Electronic Medical Record': 'Other Portable Electronic Device, Other',
                                                             'Other, Electronic Medical Record': 'Other Portable Electronic Device, Other, Electronic Medical Record',
                                                             'Desktop Computer, Paper': 'Desktop',
                                                             'Desktop Computer, Network Server': 'Desktop',
                                                             'Laptop, Desktop Computer, Network Server, E-mail': 'Desktop',
                                                             'Laptop, Other Portable Electronic Device': 'Laptop',
                                                             'Laptop, Desktop Computer, Network Server, E-mail, Other Portable Electronic Device, Other, Electronic Medical Record': 'Desktop Other',
                                                             'Desktop Computer, Network Server, Other Portable Electronic Device, Other': 'Desktop Other'})

# %%
# new_security_financial_data.value_counts()
new_security_financial_data["Place of Info Breach"].value_counts()
# Out:
# Desktop Computer                           1029
# Paper                                       587
# Other Portable Electronic Device, Other     325
# Other                                       297
# Network Server                              270
# E-mail                                      133
# Electronic Medical Record                    65
# Name: Place of Info Breach, dtype: int64

# %%
placeOfInfoBreachCounts = new_security_financial_data["Place of Info Breach"].value_counts()
placeOfInfoBreachCounts.plot.bar(color='r', alpha=0.75, align="center")
# plt.savefig('place_of_info_breach.png')
plt.savefig('place_of_info_breach_laptop_and_desktop.png', bbox_inches = "tight")

# %% [markdown]
# <h1>Adding the Pie Chart for the Method of Breach!<h1>

# %%
new_security_financial_data["Method of Breach"].value_counts()
# Out:
# hacked                 1516
# lost / stolen media     651
# inside job              285
# poor security           254
# Name: Method of Breach, dtype: int64

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise: GJM - shows 
# being Hacked is the most common type of "Method of Breach"
labels = ['hacked', 'lost / stolen', 'inside job', 'poor security']
sizes = [1516, 651, 285, 254]
explode = (0.1, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig('method_of_breach.png')
plt.show()

# %%
new_security_financial_data["Name of Business"].value_counts()
# Out:
# Citigroup                                                       483
# JP Morgan Chase                                                 267
# Countrywide Financial Corp                                      229
# Morgan Stanley Smith Barney                                     229
# TD Bank                                                         227
# Iranian banks (three:Â Saderat,Â Eghtesad Novin, andÂ Saman)    227
# Global Payments                                                 227
# Massive American business hack                                  227
# Educational Credit Management Corporation                       211
# Federal Reserve Bank of Cleveland                               211
# European Central Bank                                            56
# Korea Credit Bureau                                              56
# NASDAQ                                                           56
# Name: Name of Business, dtype: int64

# %%
new_security_financial_data["Individuals Affected"].value_counts()
# Out:
# 1000     43
# 500      43
# 2000     31
# 3000     20
# 1500     19
#          ..
# 647       1
# 17300     1
# 651       1
# 900       1
# 1924      1
# Name: Individuals Affected, Length: 771, dtype: int64

# %%
new_security_financial_data["Type of Breach"].value_counts()
# Out:
# Theft                                                         1379
# Unauthorized Access/Disclosure                                 352
# Loss                                                           224
# Other                                                          210
# Hacking/IT Incident                                            193
# Improper Disposal                                               95
# Theft, Unauthorized Access/Disclosure                           64
# Theft, Loss                                                     40
# Unknown                                                         26
# Unauthorized Access/Disclosure, Hacking/IT Incident             25
# Unauthorized Access/Disclosure, Other                           20
# Theft, Other                                                    10
# Theft, Unauthorized Access/Disclosure, Hacking/IT Incident      10
# Loss, Improper Disposal                                          7
# ...

# %%
new_security_financial_data["Year"].value_counts()
# Out:
# 2012    908
# 2011    687
# 2010    633
# 2013    254
# 2014    224
# Name: Year, dtype: int64

# %%
summary_of_events = new_security_financial_data["Summary of Events"].value_counts()
# summary_of_events = new_security_financial_data["Summary of Events"].unique()
summary_of_eventsdf = pd.DataFrame(summary_of_events)
summary_of_eventsdf.to_csv('summary_of_events.csv')
summary_of_eventsdf
# Out:
#                                                     Summary of Events
# The covered entity (CE), Long Island Consultati...                  6
# The covered entity's (CE) business associate (B...                  4
# An unencrypted laptop computer and external har...                  4
# OCR opened an investigation of the covered enti...                  4
# OCR opened an investigation of the covered enti...                  4
# ...                                                               ...
# Upon request, a subcontractor (PHM Software Sol...                  1
# Business associate (BA) employees erroneously s...                  1
# \n\nOCR opened an investigation of the covered ...                  1
# OCR opened an investigation of the covered enti...                  1
# Computer hackers installed malware that interce...                  1
#
# [112 rows x 1 columns]

# %%
# ######################################################################################

# %%
# Side by side bar chart --- GJM

# labels = ['G1', 'G2', 'G3', 'G4', 'G5']
# men_means = ['Method']
# women_means = [25, 32, 34, 20, 25]

# # the label locations
# x = np.arange(len(labels)) 

# # the width of the bars
# width = 0.35 

# fig, ax = plt.subplots()
# rects1 = ax.bar(x - width/2, men_means, width, label='Men')
# rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# # Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
# ax.set_xticks(x)
# ax.set_xticklabels(labels)
# ax.legend()


# def autolabel(rects):
#     """Attach a text label above each bar in *rects*, displaying its height."""
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')


# autolabel(rects1)
# autolabel(rects2)

# fig.tight_layout()

# plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Bar in Pie chart -- GJM

# make figure and assign axis objects
fig = plt.figure(figsize=(9, 5.0625))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
fig.subplots_adjust(wspace=0)

# pie chart parameters
ratios = [.27, .56, .17]
labels = ['Approve', 'Disapprove', 'Undecided']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * ratios[0]
ax1.pie(ratios, autopct='%1.1f%%', startangle=angle,
        labels=labels, explode=explode)

# bar chart parameters

xpos = 0
bottom = 0
ratios = [.33, .54, .07, .06]
width = .2
colors = [[.1, .3, .5], [.1, .3, .3], [.1, .3, .7], [.1, .3, .9]]

for j in range(len(ratios)):
    height = ratios[j]
    ax2.bar(xpos, height, width, bottom=bottom, color=colors[j])
    ypos = bottom + ax2.patches[j].get_height() / 2
    bottom += height
    ax2.text(xpos, ypos, "%d%%" % (ax2.patches[j].get_height() * 100),
             ha='center')

ax2.set_title('Age of approvers')
ax2.legend(('50-65', 'Over 65', '35-49', 'Under 35'))
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
# get the wedge data
theta1, theta2 = ax1.patches[0].theta1, ax1.patches[0].theta2
center, r = ax1.patches[0].center, ax1.patches[0].r
bar_height = sum([item.get_height() for item in ax2.patches])

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(- width / 2, bar_height), xyB=(x, y),
                      coordsA="data", coordsB="data", axesA=ax2, axesB=ax1)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(- width / 2, 0), xyB=(x, y), coordsA="data",
                      coordsB="data", axesA=ax2, axesB=ax1)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
users = [13000, 26000, 52000, 30000, 9000]
x_axis = np.arange(len(users))

# %%
# Tell matplotlib that we will be making a bar chart
# Users is our y axis and x_axis is, of course, our x axis
# We apply align="edge" to ensure our bars line up with our tick marks
plt.bar(x_axis, users, color='r', alpha=0.75, align="center")
# Out:
# <BarContainer object of 5 artists>

# %%
# price_list = df["price"].tolist()
# prices = []
# for item in price_list:
#     check = item[0:3]
#     if check == "USD":
#         price = item[3:]
#     else:
#         price = "NA"
#     prices.append(price)

# df2 = df.drop(columns=["price"])
# df2["price"]=prices
# df2.to_csv("../data/island_info.csv")
